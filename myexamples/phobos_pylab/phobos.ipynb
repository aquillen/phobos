# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import autoreload
# %load_ext autoreload
# %autoreload 2
from orbsubs import *   
# subroutines for plotting in orbsubs_ur
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
simdir = "../phobos/" # where simulation output files are to be found
numberpm=1  # number of point masses in simulation

# %%
parmfile='a1'  # parameter file for simulation
fileroot = simdir + parmfile  
plt_cols(fileroot,numberpm,parmfile + '.png',0,0)  #  savefile, then tmin,tmax
# Out:
# ../phobos/a1_ext.txt
# ../phobos/a1_pm0.txt
# kk= 4

# %%
tt,mvec,aaarr,eearr,iiarr,lnarr,ararr,maarr,obliq_deg,spin,Jvec,\
  prec_ang,phi_Eu,theta_Eu,bphi_Eu,dEdtnow,dEdtave,Ivec=orbels_arr(fileroot,numberpm)


# tt is time vector
# eearr[0] is orbital eccentricity vector of resolved body
# aaaar[0] is semi-major axis vector of resolved body
# dEdt is energy dissipated
# Jvec is non principal angle
# spin is spin rate
# obliquity_deg is obliquity in degrees
# Ivec contains moment of inertial eigenvalues

plt.plot(eearr[0,10:],np.log10(dEdtave[10:]),'.')
# Out:
# ../phobos/a1_ext.txt
# ../phobos/a1_pm0.txt
# kk= 4

# %%
plt.plot(tt,np.log10(eearr[0]),'.')
#plt.xlim([1.5e5,max(tt)])

# %%
10**-1.83
# Out:
# 0.014791083881682071
